# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from Dependency.GraphCoordinate import *

# %%
data = [[0,2,2, True], [3,4,5, True], [4,2,2, True], [3,7,5,True], [10, 10, 10, False]]


doc = NodeGroupDisplay()
Xcorr, Ycorr, MasterGrp = doc.NodeGroupDisplay(data)
plt.show
print(Xcorr, Ycorr, MasterGrp)
# Out:
# [0, 3, 4, 3, 10] [2, 4, 2, 7, 10] ['k', 'b', 'k', 'b', 'g']

# %%
plt.scatter(Xcorr, Ycorr, c = MasterGrp, s = 100)

# %%
import numpy as np
import matplotlib.pyplot as plt

#generate some fake data
x = np.random.random(10000)*10
y = np.random.random(10000)*10

col = np.where(x<1,'k',np.where(y<5,'b','r'))

plt.scatter(x, y, c=col, s=5, linewidth=0)
plt.show()
